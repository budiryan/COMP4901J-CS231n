# %% [markdown]
# # Model-Based RL
# In this exercise you will implement a policy and model network which work in tandem to solve the CartPole reinforcement learning problem.

# %% [markdown]
# What is a model and why would we want to use one? In this case, a model is going to be a neural network that attempts to learn the dynamics of the real environment. For example, in the CartPole we would like a model to be able to predict the next position of the Cart given the previous position and an action. By learning an accurate model, we can train our agent using the model rather than requiring to use the real environment every time. While this may seem less useful when the real environment is itself a simulation, like in our CartPole task, it can have huge advantages when attempting to learn policies for acting in the physical world.

# %% [markdown]
# How are we going to accomplish this in Tensorflow? We are going to be using a neural network that will learn the transition dynamics between a previous observation and action, and the expected new observation, reward, and done state. Our training procedure will involve switching between training our model using the real environment, and training our agent’s policy using the model environment. By using this approach we will be able to learn a policy that allows our agent to solve the CartPole task without actually ever training the policy on the real environment!

# %% [markdown]
# ### Loading libraries and starting CartPole environment

# %%
from __future__ import print_function
import numpy as np
try:
    import cPickle as pickle
except:
    import pickle
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %%
import sys
if sys.version_info.major > 2:
    xrange = range
del sys

# %%
import gym
env = gym.make('CartPole-v0')

# %% [markdown]
# ### Setting Hyper-parameters

# %%
# hyperparameters
H = 8 # number of hidden layer neurons
learning_rate = 1e-2
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
resume = False # resume from previous checkpoint?

model_bs = 3 # Batch size when learning from model
real_bs = 3 # Batch size when learning from real environment

# model initialization
D = 4 # input dimensionality

# %% [markdown]
# ### Policy Network

# %%
tf.reset_default_graph()
observations = tf.placeholder(tf.float32, [None,4] , name="input_x")
W1 = tf.get_variable("W1", shape=[4, H],
           initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations,W1))
W2 = tf.get_variable("W2", shape=[H, 1],
           initializer=tf.contrib.layers.xavier_initializer())
score = tf.matmul(layer1,W2)
probability = tf.nn.sigmoid(score)

tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32,[None,1], name="input_y")
advantages = tf.placeholder(tf.float32,name="reward_signal")
adam = tf.train.AdamOptimizer(learning_rate=learning_rate)
W1Grad = tf.placeholder(tf.float32,name="batch_grad1")
W2Grad = tf.placeholder(tf.float32,name="batch_grad2")
batchGrad = [W1Grad,W2Grad]

################################################################################
# TODO: Implement the loss function.                                           #
# This sends the weights in the direction of making actions that gave good     #
# advantage (reward overtime) more likely, and actions that didn't less likely.#
################################################################################
loglik = tf.log(input_y*(input_y - probability) + (1 - input_y)*(input_y + probability))
loss = -tf.reduce_mean(loglik * advantages) 
newGrads = tf.gradients(loss,tvars)
adam = tf.train.AdamOptimizer(learning_rate=learning_rate) # Our optimizer
################################################################################
#                                 END OF YOUR CODE                             #
################################################################################

newGrads = tf.gradients(loss,tvars)
updateGrads = adam.apply_gradients(zip(batchGrad,tvars))

# %% [markdown]
# ### Model Network
# Here we implement a multi-layer neural network that predicts the next observation, reward, and done state from a current state and action.

# %%
mH = 256 # model layer size

input_data = tf.placeholder(tf.float32, [None, 5])
with tf.variable_scope('rnnlm'):
    softmax_w = tf.get_variable("softmax_w", [mH, 50])
    softmax_b = tf.get_variable("softmax_b", [50])

previous_state = tf.placeholder(tf.float32, [None,5] , name="previous_state")
W1M = tf.get_variable("W1M", shape=[5, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B1M = tf.Variable(tf.zeros([mH]),name="B1M")
layer1M = tf.nn.relu(tf.matmul(previous_state,W1M) + B1M)
W2M = tf.get_variable("W2M", shape=[mH, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B2M = tf.Variable(tf.zeros([mH]),name="B2M")
layer2M = tf.nn.relu(tf.matmul(layer1M,W2M) + B2M)
wO = tf.get_variable("wO", shape=[mH, 4],
           initializer=tf.contrib.layers.xavier_initializer())
wR = tf.get_variable("wR", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())
wD = tf.get_variable("wD", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())

bO = tf.Variable(tf.zeros([4]),name="bO")
bR = tf.Variable(tf.zeros([1]),name="bR")
bD = tf.Variable(tf.ones([1]),name="bD")


predicted_observation = tf.matmul(layer2M,wO,name="predicted_observation") + bO
predicted_reward = tf.matmul(layer2M,wR,name="predicted_reward") + bR
predicted_done = tf.sigmoid(tf.matmul(layer2M,wD,name="predicted_done") + bD)

true_observation = tf.placeholder(tf.float32,[None,4],name="true_observation")
true_reward = tf.placeholder(tf.float32,[None,1],name="true_reward")
true_done = tf.placeholder(tf.float32,[None,1],name="true_done")


predicted_state = tf.concat([predicted_observation,predicted_reward,predicted_done],1)

observation_loss = tf.square(true_observation - predicted_observation)

reward_loss = tf.square(true_reward - predicted_reward)

done_loss = tf.multiply(predicted_done, true_done) + tf.multiply(1-predicted_done, 1-true_done)
done_loss = -tf.log(done_loss)

model_loss = tf.reduce_mean(observation_loss + done_loss + reward_loss)

modelAdam = tf.train.AdamOptimizer(learning_rate=learning_rate)
updateModel = modelAdam.minimize(model_loss)

# %% [markdown]
# ### Helper-functions

# %%
def resetGradBuffer(gradBuffer):
    for ix,grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0
    return gradBuffer

def discount_rewards(r):
    ################################################################################
    # TODO: Implement the discounted rewards function                              #
    # Return discounted rewards weighed by gamma. Each reward will be replaced     #
    # with a weight reward that involves itself and all the other rewards occuring #
    # after it. The later the reward after it happens, the less effect it has on   #
    # the current rewards's discounted reward                                      #
    # Hint: [r0, r1, r2, ..., r_N] will look someting like:                        #
    #       [(r0 + r1*gamma^1 + ... r_N*gamma^N), (r1 + r2*gamma^1 + ...), ...]    #
    ################################################################################
    discounted_rewards = np.zeros(r.shape)
    running_discount = 0
    for i in reversed(range(len(r))):
        running_discount = running_discount * gamma + r[i]
        discounted_rewards[i] = running_discount
    return discounted_rewards
    ################################################################################
    #                                 END OF YOUR CODE                             #
    ################################################################################

# This function uses our model to produce a new state when given a previous state and action
def stepModel(sess, xs, action):
    toFeed = np.reshape(np.hstack([xs[-1][0],np.array(action)]),[1,5])
    myPredict = sess.run([predicted_state],feed_dict={previous_state: toFeed})
    reward = myPredict[0][:,4]
    observation = myPredict[0][:,0:4]
    observation[:,0] = np.clip(observation[:,0],-2.4,2.4)
    observation[:,2] = np.clip(observation[:,2],-0.4,0.4)
    doneP = np.clip(myPredict[0][:,5],0,1)
    if doneP > 0.1 or len(xs)>= 300:
        done = True
    else:
        done = False
    return observation, reward, done

# %% [markdown]
# ## Training the Policy and Model

# %%
xs,drs,ys,ds = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 1
real_episodes = 1
init = tf.global_variables_initializer()
batch_size = real_bs

drawFromModel = False # When set to True, will use model for observations
trainTheModel = True # Whether to train the model
trainThePolicy = False # Whether to train the policy
switch_point = 1

# Launch the graph
with tf.Session() as sess:
    rendering = False
    sess.run(init)
    observation = env.reset()
    x = observation
    gradBuffer = sess.run(tvars)
    gradBuffer = resetGradBuffer(gradBuffer)
    
    while episode_number <= 5000:
        # Start displaying environment once performance is acceptably high.
        if (reward_sum/batch_size > 150 and drawFromModel == False) or rendering == True : 
            env.render()
            rendering = True
            
        x = np.reshape(observation,[1,4])

        tfprob = sess.run(probability,feed_dict={observations: x})
        action = 1 if np.random.uniform() < tfprob else 0

        # record various intermediates (needed later for backprop)
        xs.append(x) 
        y = 1 if action == 0 else 0 
        ys.append(y)
        
        # step the  model or real environment and get new measurements
        if drawFromModel == False:
            observation, reward, done, info = env.step(action)
        else:
            observation, reward, done = stepModel(sess,xs,action)
                
        reward_sum += reward
        
        ds.append(done*1)
        drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

        if done: 
            
            if drawFromModel == False: 
                real_episodes += 1
            episode_number += 1

            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            epd = np.vstack(ds)
            xs,drs,ys,ds = [],[],[],[] # reset array memory
            
            if trainTheModel == True:
                ################################################################################
                # TODO: Run the model network and compute predicted_state                      #
                # Output: 'pState'                                                             #
                ################################################################################
                actions = np.array([np.abs(y-1) for y in epy][:-1])
                
                # Get all the prev variables
                prev_state = epx[: -1, :]
                prev_state = np.hstack([prev_state,actions])
                
                # Get all the variables for next state
                next_state = epx[1: , :]
                rewards = np.array(epr[1: , :])
                dones = np.array(epd[1: , :])

                pState, _ = sess.run([predicted_state,updateModel],feed_dict={previous_state: prev_state, 
                                                                              true_observation: next_state,
                                                                              true_done:dones,
                                                                              true_reward:rewards})
                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################
                

            if trainThePolicy == True:
                ################################################################################
                # TODO: Run the policy network and compute newGrads                            #
                # Output: 'tGrad'                                                              #
                ################################################################################
                # compute the discounted reward backwards through time
                discounted_epr = discount_rewards(epr)
                # size the rewards to be unit normal (helps control the gradient estimator variance)
                discounted_epr -= np.mean(discounted_epr)
                discounted_epr //= np.std(discounted_epr)
                tGrad = sess.run(newGrads, feed_dict={input_y: epy, observations: epx, advantages: discounted_epr})
                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################
                
                # If gradients becom too large, end training process
                if np.sum(tGrad[0] == tGrad[0]) == 0:
                    break
                for ix,grad in enumerate(tGrad):
                    gradBuffer[ix] += grad
                
            if switch_point + batch_size == episode_number: 
                switch_point = episode_number
                if trainThePolicy == True:
                    
                    ################################################################################
                    # TODO:                                                                        #
                    # (1) Run the policy network and update gradients                              #
                    # (2) Reset gradBuffer to 0                                                    #
                    ################################################################################
                    _ = sess.run(updateGrads, feed_dict={W1Grad: gradBuffer[0], 
                                                         W2Grad: gradBuffer[1]})
                    for ix,grad in enumerate(gradBuffer):
                        gradBuffer[ix] = grad * 0
                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################

                running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
                if drawFromModel == False:
                    print('World Perf: Episode %f. Reward %f. action: %f. mean reward %f.' % (real_episodes,reward_sum/real_bs,action, running_reward/real_bs))
                    if reward_sum/batch_size >= 200:
                        break
                reward_sum = 0

                # Once the model has been trained on 100 episodes
                if episode_number > 100:

                    ################################################################################
                    # TODO: Alternating between training the policy from the model and training    #
                    # the model from the real environment.                                         #
                    ################################################################################
                    trainThePolicy = not trainThePolicy # Whether to train the policy
                    trainTheModel = not trainTheModel # Whether to train the model
                    drawFromModel = not drawFromModel # When set to True, will use model for observations

                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################
            
            if drawFromModel == True:
                observation = np.random.uniform(-0.1,0.1,[4]) # Generate reasonable starting point
                batch_size = model_bs
            else:
                observation = env.reset()
                batch_size = real_bs
                
print(real_episodes)
# Out:
# World Perf: Episode 4.000000. Reward 31.000000. action: 1.000000. mean reward 31.000000.
# World Perf: Episode 7.000000. Reward 16.333333. action: 0.000000. mean reward 30.853333.
# World Perf: Episode 10.000000. Reward 17.333333. action: 0.000000. mean reward 30.718133.
# World Perf: Episode 13.000000. Reward 19.333333. action: 0.000000. mean reward 30.604285.
# World Perf: Episode 16.000000. Reward 12.000000. action: 1.000000. mean reward 30.418242.
# World Perf: Episode 19.000000. Reward 29.000000. action: 1.000000. mean reward 30.404060.
# World Perf: Episode 22.000000. Reward 16.000000. action: 1.000000. mean reward 30.260019.
# World Perf: Episode 25.000000. Reward 20.333333. action: 1.000000. mean reward 30.160753.
# World Perf: Episode 28.000000. Reward 12.333333. action: 1.000000. mean reward 29.982478.
# World Perf: Episode 31.000000. Reward 30.333333. action: 0.000000. mean reward 29.985987.
# World Perf: Episode 34.000000. Reward 13.333333. action: 0.000000. mean reward 29.819460.
# World Perf: Episode 37.000000. Reward 13.666667. action: 1.000000. mean reward 29.657932.
# World Perf: Episode 40.000000. Reward 27.333333. action: 1.000000. mean reward 29.634686.
# World Perf: Episode 43.000000. Reward 21.666667. action: 1.000000. mean reward 29.555006.
# World Perf: Episode 46.000000. Reward 16.000000. action: 1.000000. mean reward 29.419456.
# World Perf: Episode 49.000000. Reward 21.333333. action: 1.000000. mean reward 29.338595.
# World Perf: Episode 52.000000. Reward 17.000000. action: 1.000000. mean reward 29.215209.
# World Perf: Episode 55.000000. Reward 16.333333. action: 1.000000. mean reward 29.086390.
# World Perf: Episode 58.000000. Reward 20.333333. action: 1.000000. mean reward 28.998860.
# World Perf: Episode 61.000000. Reward 18.000000. action: 1.000000. mean reward 28.888871.
# World Perf: Episode 64.000000. Reward 23.333333. action: 1.000000. mean reward 28.833316.
# World Perf: Episode 67.000000. Reward 24.666667. action: 0.000000. mean reward 28.791649.
# World Perf: Episode 70.000000. Reward 14.000000. action: 1.000000. mean reward 28.643733.
# World Perf: Episode 73.000000. Reward 18.666667. action: 0.000000. mean reward 28.543962.
# World Perf: Episode 76.000000. Reward 14.000000. action: 1.000000. mean reward 28.398522.
# World Perf: Episode 79.000000. Reward 13.000000. action: 1.000000. mean reward 28.244537.
# World Perf: Episode 82.000000. Reward 11.333333. action: 0.000000. mean reward 28.075425.
# World Perf: Episode 85.000000. Reward 12.666667. action: 0.000000. mean reward 27.921338.
# World Perf: Episode 88.000000. Reward 17.000000. action: 1.000000. mean reward 27.812124.
# World Perf: Episode 91.000000. Reward 23.000000. action: 0.000000. mean reward 27.764003.
# World Perf: Episode 94.000000. Reward 20.333333. action: 0.000000. mean reward 27.689696.
# World Perf: Episode 97.000000. Reward 21.666667. action: 1.000000. mean reward 27.629466.
# World Perf: Episode 100.000000. Reward 18.000000. action: 1.000000. mean reward 27.533171.
# World Perf: Episode 103.000000. Reward 28.333333. action: 1.000000. mean reward 27.541173.
# World Perf: Episode 106.000000. Reward 48.666667. action: 0.000000. mean reward 27.695543.
# World Perf: Episode 109.000000. Reward 18.333333. action: 0.000000. mean reward 27.477282.
# World Perf: Episode 112.000000. Reward 24.666667. action: 1.000000. mean reward 27.260382.
# World Perf: Episode 115.000000. Reward 16.000000. action: 1.000000. mean reward 27.069399.
# World Perf: Episode 118.000000. Reward 25.333333. action: 1.000000. mean reward 27.322802.
# World Perf: Episode 121.000000. Reward 29.666667. action: 1.000000. mean reward 27.207026.
# World Perf: Episode 124.000000. Reward 27.333333. action: 1.000000. mean reward 27.137697.
# World Perf: Episode 127.000000. Reward 28.333333. action: 1.000000. mean reward 27.173613.
# World Perf: Episode 130.000000. Reward 21.000000. action: 0.000000. mean reward 26.950911.
# World Perf: Episode 133.000000. Reward 19.666667. action: 1.000000. mean reward 26.771332.
# World Perf: Episode 136.000000. Reward 23.333333. action: 1.000000. mean reward 27.328802.
# World Perf: Episode 139.000000. Reward 30.000000. action: 0.000000. mean reward 27.210264.
# World Perf: Episode 142.000000. Reward 17.666667. action: 1.000000. mean reward 26.961136.
# World Perf: Episode 145.000000. Reward 20.000000. action: 1.000000. mean reward 26.739214.
# World Perf: Episode 148.000000. Reward 30.666667. action: 0.000000. mean reward 26.731043.
# World Perf: Episode 151.000000. Reward 17.000000. action: 0.000000. mean reward 26.592676.
# World Perf: Episode 154.000000. Reward 19.666667. action: 0.000000. mean reward 26.408243.
# World Perf: Episode 157.000000. Reward 13.000000. action: 1.000000. mean reward 26.080786.
# World Perf: Episode 160.000000. Reward 37.333333. action: 1.000000. mean reward 26.038826.
# World Perf: Episode 163.000000. Reward 27.000000. action: 0.000000. mean reward 26.060392.
# World Perf: Episode 166.000000. Reward 18.000000. action: 1.000000. mean reward 25.885727.
# World Perf: Episode 169.000000. Reward 38.000000. action: 1.000000. mean reward 27.165945.
# World Perf: Episode 172.000000. Reward 41.333333. action: 0.000000. mean reward 27.135984.
# World Perf: Episode 175.000000. Reward 37.000000. action: 1.000000. mean reward 27.303595.
# World Perf: Episode 178.000000. Reward 57.666667. action: 1.000000. mean reward 29.693441.
# World Perf: Episode 181.000000. Reward 26.666667. action: 0.000000. mean reward 29.496803.
# World Perf: Episode 184.000000. Reward 36.333333. action: 1.000000. mean reward 29.495806.
# World Perf: Episode 187.000000. Reward 40.666667. action: 0.000000. mean reward 29.612183.
# World Perf: Episode 190.000000. Reward 42.666667. action: 1.000000. mean reward 29.567009.
# World Perf: Episode 193.000000. Reward 46.333333. action: 1.000000. mean reward 29.772764.
# World Perf: Episode 196.000000. Reward 32.333333. action: 1.000000. mean reward 29.679672.
# World Perf: Episode 199.000000. Reward 21.333333. action: 1.000000. mean reward 29.854887.
# World Perf: Episode 202.000000. Reward 27.000000. action: 0.000000. mean reward 30.793028.
# World Perf: Episode 205.000000. Reward 30.000000. action: 0.000000. mean reward 30.914007.
# World Perf: Episode 208.000000. Reward 34.333333. action: 0.000000. mean reward 30.744001.
# World Perf: Episode 211.000000. Reward 30.333333. action: 1.000000. mean reward 30.654823.
# World Perf: Episode 214.000000. Reward 44.000000. action: 1.000000. mean reward 31.366728.
# World Perf: Episode 217.000000. Reward 26.000000. action: 1.000000. mean reward 31.530203.
# World Perf: Episode 220.000000. Reward 37.333333. action: 1.000000. mean reward 34.062122.
# World Perf: Episode 223.000000. Reward 42.666667. action: 1.000000. mean reward 34.003429.
# World Perf: Episode 226.000000. Reward 38.333333. action: 1.000000. mean reward 33.899754.
# World Perf: Episode 229.000000. Reward 35.000000. action: 1.000000. mean reward 33.739437.
# World Perf: Episode 232.000000. Reward 17.666667. action: 0.000000. mean reward 33.517570.
# World Perf: Episode 235.000000. Reward 35.333333. action: 1.000000. mean reward 33.330765.
# World Perf: Episode 238.000000. Reward 16.333333. action: 1.000000. mean reward 32.962902.
# World Perf: Episode 241.000000. Reward 53.000000. action: 1.000000. mean reward 33.573990.
# World Perf: Episode 244.000000. Reward 25.333333. action: 1.000000. mean reward 33.400654.
# World Perf: Episode 247.000000. Reward 42.000000. action: 0.000000. mean reward 33.241013.
# World Perf: Episode 250.000000. Reward 32.333333. action: 1.000000. mean reward 33.068619.
# World Perf: Episode 253.000000. Reward 36.333333. action: 1.000000. mean reward 33.071285.
# World Perf: Episode 256.000000. Reward 28.000000. action: 0.000000. mean reward 32.759655.
# World Perf: Episode 259.000000. Reward 33.000000. action: 0.000000. mean reward 32.615318.
# World Perf: Episode 262.000000. Reward 32.333333. action: 0.000000. mean reward 32.393307.
# World Perf: Episode 265.000000. Reward 17.000000. action: 0.000000. mean reward 31.978365.
# World Perf: Episode 268.000000. Reward 51.666667. action: 1.000000. mean reward 32.022652.
# World Perf: Episode 271.000000. Reward 18.666667. action: 0.000000. mean reward 32.490170.
# World Perf: Episode 274.000000. Reward 35.000000. action: 0.000000. mean reward 32.358562.
# World Perf: Episode 277.000000. Reward 25.333333. action: 0.000000. mean reward 34.845421.
# World Perf: Episode 280.000000. Reward 51.333333. action: 1.000000. mean reward 35.584133.
# World Perf: Episode 283.000000. Reward 52.333333. action: 1.000000. mean reward 35.493759.
# World Perf: Episode 286.000000. Reward 38.000000. action: 1.000000. mean reward 35.298679.
# World Perf: Episode 289.000000. Reward 45.000000. action: 0.000000. mean reward 35.220181.
# World Perf: Episode 292.000000. Reward 47.666667. action: 0.000000. mean reward 35.435940.
# World Perf: Episode 295.000000. Reward 38.000000. action: 1.000000. mean reward 35.446995.
# World Perf: Episode 298.000000. Reward 21.000000. action: 0.000000. mean reward 35.475925.
# World Perf: Episode 301.000000. Reward 36.333333. action: 1.000000. mean reward 35.268795.
# World Perf: Episode 304.000000. Reward 25.666667. action: 1.000000. mean reward 34.951591.
# World Perf: Episode 307.000000. Reward 29.333333. action: 0.000000. mean reward 39.029591.
# World Perf: Episode 310.000000. Reward 27.666667. action: 1.000000. mean reward 42.936966.
# World Perf: Episode 313.000000. Reward 33.000000. action: 1.000000. mean reward 42.655804.
# World Perf: Episode 316.000000. Reward 34.000000. action: 1.000000. mean reward 42.644539.
# World Perf: Episode 319.000000. Reward 59.666667. action: 0.000000. mean reward 42.590691.
# World Perf: Episode 322.000000. Reward 72.333333. action: 1.000000. mean reward 42.665928.
# World Perf: Episode 325.000000. Reward 29.000000. action: 0.000000. mean reward 42.317402.
# World Perf: Episode 328.000000. Reward 51.000000. action: 0.000000. mean reward 42.242348.
# World Perf: Episode 331.000000. Reward 39.333333. action: 0.000000. mean reward 42.343266.
# World Perf: Episode 334.000000. Reward 31.666667. action: 0.000000. mean reward 41.940266.
# World Perf: Episode 337.000000. Reward 28.333333. action: 0.000000. mean reward 41.738449.
# World Perf: Episode 340.000000. Reward 35.000000. action: 1.000000. mean reward 41.421185.
# World Perf: Episode 343.000000. Reward 51.333333. action: 1.000000. mean reward 41.194618.
# World Perf: Episode 346.000000. Reward 46.666667. action: 0.000000. mean reward 41.347008.
# World Perf: Episode 349.000000. Reward 55.333333. action: 1.000000. mean reward 41.286472.
# World Perf: Episode 352.000000. Reward 46.666667. action: 0.000000. mean reward 41.079571.
# World Perf: Episode 355.000000. Reward 33.000000. action: 1.000000. mean reward 43.337341.
# World Perf: Episode 358.000000. Reward 19.666667. action: 0.000000. mean reward 42.754658.
# World Perf: Episode 361.000000. Reward 44.000000. action: 1.000000. mean reward 44.112011.
# World Perf: Episode 364.000000. Reward 38.000000. action: 0.000000. mean reward 43.755772.
# World Perf: Episode 367.000000. Reward 20.000000. action: 0.000000. mean reward 43.473820.
# World Perf: Episode 370.000000. Reward 43.333333. action: 0.000000. mean reward 43.151348.
# World Perf: Episode 373.000000. Reward 39.333333. action: 0.000000. mean reward 43.479023.
# World Perf: Episode 376.000000. Reward 52.333333. action: 0.000000. mean reward 43.539021.
# World Perf: Episode 379.000000. Reward 17.666667. action: 1.000000. mean reward 43.138180.
# World Perf: Episode 382.000000. Reward 22.000000. action: 0.000000. mean reward 42.698635.
# World Perf: Episode 385.000000. Reward 53.666667. action: 0.000000. mean reward 42.518005.
# World Perf: Episode 388.000000. Reward 56.000000. action: 0.000000. mean reward 42.291168.
# World Perf: Episode 391.000000. Reward 69.333333. action: 0.000000. mean reward 42.215809.
# World Perf: Episode 394.000000. Reward 53.000000. action: 1.000000. mean reward 42.131229.
# World Perf: Episode 397.000000. Reward 44.333333. action: 0.000000. mean reward 41.947384.
# World Perf: Episode 400.000000. Reward 34.666667. action: 1.000000. mean reward 41.639774.
# World Perf: Episode 403.000000. Reward 47.000000. action: 1.000000. mean reward 44.813782.
# World Perf: Episode 406.000000. Reward 56.666667. action: 0.000000. mean reward 44.877991.
# World Perf: Episode 409.000000. Reward 34.000000. action: 0.000000. mean reward 44.400730.
# World Perf: Episode 412.000000. Reward 35.333333. action: 1.000000. mean reward 43.923096.
# World Perf: Episode 415.000000. Reward 56.333333. action: 0.000000. mean reward 43.716679.
# World Perf: Episode 418.000000. Reward 78.333333. action: 1.000000. mean reward 43.732731.
# World Perf: Episode 421.000000. Reward 70.333333. action: 0.000000. mean reward 43.771023.
# World Perf: Episode 424.000000. Reward 34.666667. action: 0.000000. mean reward 46.077808.
# World Perf: Episode 427.000000. Reward 47.000000. action: 1.000000. mean reward 45.911312.
# World Perf: Episode 430.000000. Reward 52.000000. action: 1.000000. mean reward 45.678959.
# World Perf: Episode 433.000000. Reward 43.000000. action: 0.000000. mean reward 45.255009.
# World Perf: Episode 436.000000. Reward 33.333333. action: 1.000000. mean reward 44.813709.
# World Perf: Episode 439.000000. Reward 52.666667. action: 0.000000. mean reward 44.746799.
# World Perf: Episode 442.000000. Reward 76.666667. action: 1.000000. mean reward 44.675259.
# World Perf: Episode 445.000000. Reward 60.333333. action: 0.000000. mean reward 44.487522.
# World Perf: Episode 448.000000. Reward 50.333333. action: 0.000000. mean reward 44.376751.
# World Perf: Episode 451.000000. Reward 56.000000. action: 0.000000. mean reward 44.197491.
# World Perf: Episode 454.000000. Reward 44.666667. action: 1.000000. mean reward 44.065495.
# World Perf: Episode 457.000000. Reward 51.000000. action: 0.000000. mean reward 46.801975.
# World Perf: Episode 460.000000. Reward 64.000000. action: 1.000000. mean reward 47.096317.
# World Perf: Episode 463.000000. Reward 36.666667. action: 0.000000. mean reward 46.626942.
# World Perf: Episode 466.000000. Reward 35.666667. action: 1.000000. mean reward 46.403973.
# World Perf: Episode 469.000000. Reward 61.666667. action: 1.000000. mean reward 46.190617.
# World Perf: Episode 472.000000. Reward 50.000000. action: 0.000000. mean reward 45.890125.
# World Perf: Episode 475.000000. Reward 58.333333. action: 0.000000. mean reward 45.709965.
# World Perf: Episode 478.000000. Reward 62.666667. action: 0.000000. mean reward 45.511288.
# World Perf: Episode 481.000000. Reward 92.666667. action: 0.000000. mean reward 45.841614.
# World Perf: Episode 484.000000. Reward 45.000000. action: 1.000000. mean reward 46.405640.
# World Perf: Episode 487.000000. Reward 66.333333. action: 1.000000. mean reward 46.514545.
# World Perf: Episode 490.000000. Reward 58.333333. action: 0.000000. mean reward 46.260082.
# World Perf: Episode 493.000000. Reward 43.666667. action: 0.000000. mean reward 45.909393.
# World Perf: Episode 496.000000. Reward 94.666667. action: 0.000000. mean reward 46.212418.
# World Perf: Episode 499.000000. Reward 76.000000. action: 1.000000. mean reward 48.985683.
# World Perf: Episode 502.000000. Reward 55.000000. action: 0.000000. mean reward 48.910950.
# World Perf: Episode 505.000000. Reward 91.000000. action: 0.000000. mean reward 49.158428.
# World Perf: Episode 508.000000. Reward 87.000000. action: 1.000000. mean reward 49.197491.
# World Perf: Episode 511.000000. Reward 72.666667. action: 0.000000. mean reward 55.783833.
# World Perf: Episode 514.000000. Reward 113.000000. action: 1.000000. mean reward 56.615875.
# World Perf: Episode 517.000000. Reward 34.666667. action: 1.000000. mean reward 58.329998.
# World Perf: Episode 520.000000. Reward 98.666667. action: 1.000000. mean reward 58.263474.
# World Perf: Episode 523.000000. Reward 62.666667. action: 0.000000. mean reward 57.864498.
# World Perf: Episode 526.000000. Reward 72.333333. action: 0.000000. mean reward 57.511505.
# World Perf: Episode 529.000000. Reward 88.000000. action: 0.000000. mean reward 57.397537.
# World Perf: Episode 532.000000. Reward 67.333333. action: 0.000000. mean reward 57.073109.
# World Perf: Episode 535.000000. Reward 67.666667. action: 0.000000. mean reward 56.750397.
# World Perf: Episode 538.000000. Reward 52.000000. action: 1.000000. mean reward 56.341244.
# World Perf: Episode 541.000000. Reward 95.333333. action: 0.000000. mean reward 56.334003.
# World Perf: Episode 544.000000. Reward 84.333333. action: 0.000000. mean reward 56.242172.
# World Perf: Episode 547.000000. Reward 41.333333. action: 0.000000. mean reward 55.697277.
# World Perf: Episode 550.000000. Reward 60.666667. action: 1.000000. mean reward 58.382648.
# World Perf: Episode 553.000000. Reward 49.666667. action: 1.000000. mean reward 57.937160.
# World Perf: Episode 556.000000. Reward 111.333333. action: 0.000000. mean reward 58.627460.
# World Perf: Episode 559.000000. Reward 79.000000. action: 0.000000. mean reward 64.154091.
# World Perf: Episode 562.000000. Reward 70.000000. action: 1.000000. mean reward 64.715202.
# World Perf: Episode 565.000000. Reward 68.000000. action: 0.000000. mean reward 64.190010.
# World Perf: Episode 568.000000. Reward 69.333333. action: 0.000000. mean reward 63.710705.
# World Perf: Episode 571.000000. Reward 89.666667. action: 0.000000. mean reward 67.419662.
# World Perf: Episode 574.000000. Reward 57.000000. action: 0.000000. mean reward 66.802681.
# World Perf: Episode 577.000000. Reward 91.000000. action: 1.000000. mean reward 66.550163.
# World Perf: Episode 580.000000. Reward 89.333333. action: 1.000000. mean reward 66.636261.
# World Perf: Episode 583.000000. Reward 42.666667. action: 0.000000. mean reward 65.907692.
# World Perf: Episode 586.000000. Reward 65.333333. action: 0.000000. mean reward 68.082756.
# World Perf: Episode 589.000000. Reward 51.666667. action: 0.000000. mean reward 67.416367.
# World Perf: Episode 592.000000. Reward 44.333333. action: 0.000000. mean reward 66.817383.
# World Perf: Episode 595.000000. Reward 67.000000. action: 0.000000. mean reward 66.381783.
# World Perf: Episode 598.000000. Reward 83.000000. action: 0.000000. mean reward 66.146049.
# World Perf: Episode 601.000000. Reward 73.333333. action: 0.000000. mean reward 65.712563.
# World Perf: Episode 604.000000. Reward 42.666667. action: 1.000000. mean reward 65.083511.
# World Perf: Episode 607.000000. Reward 89.000000. action: 1.000000. mean reward 64.861382.
# World Perf: Episode 610.000000. Reward 83.000000. action: 0.000000. mean reward 64.644844.
# World Perf: Episode 613.000000. Reward 71.000000. action: 1.000000. mean reward 64.643188.
# World Perf: Episode 616.000000. Reward 51.000000. action: 0.000000. mean reward 64.331871.
# World Perf: Episode 619.000000. Reward 117.333333. action: 0.000000. mean reward 64.622902.
# World Perf: Episode 622.000000. Reward 97.000000. action: 0.000000. mean reward 66.386230.
# World Perf: Episode 625.000000. Reward 103.333333. action: 0.000000. mean reward 66.303894.
# World Perf: Episode 628.000000. Reward 58.000000. action: 1.000000. mean reward 65.806999.
# World Perf: Episode 631.000000. Reward 60.333333. action: 0.000000. mean reward 66.161118.
# World Perf: Episode 634.000000. Reward 93.666667. action: 0.000000. mean reward 65.990204.
# World Perf: Episode 637.000000. Reward 76.333333. action: 0.000000. mean reward 65.699089.
# World Perf: Episode 640.000000. Reward 111.666667. action: 0.000000. mean reward 65.693611.
# World Perf: Episode 643.000000. Reward 87.000000. action: 1.000000. mean reward 65.584831.
# World Perf: Episode 646.000000. Reward 60.333333. action: 0.000000. mean reward 65.101578.
# World Perf: Episode 649.000000. Reward 55.000000. action: 0.000000. mean reward 64.601074.
# World Perf: Episode 652.000000. Reward 58.666667. action: 0.000000. mean reward 64.352394.
# World Perf: Episode 655.000000. Reward 126.000000. action: 0.000000. mean reward 67.178398.
# World Perf: Episode 658.000000. Reward 118.666667. action: 1.000000. mean reward 69.728828.
# World Perf: Episode 661.000000. Reward 72.000000. action: 0.000000. mean reward 69.359543.
# World Perf: Episode 664.000000. Reward 124.000000. action: 1.000000. mean reward 69.329086.
# World Perf: Episode 667.000000. Reward 128.333333. action: 0.000000. mean reward 69.530655.
# World Perf: Episode 670.000000. Reward 143.333333. action: 1.000000. mean reward 69.766205.
# World Perf: Episode 673.000000. Reward 153.000000. action: 1.000000. mean reward 70.570419.
# World Perf: Episode 676.000000. Reward 118.333333. action: 1.000000. mean reward 70.461525.
# World Perf: Episode 679.000000. Reward 87.666667. action: 0.000000. mean reward 70.071144.
# World Perf: Episode 682.000000. Reward 67.000000. action: 0.000000. mean reward 72.931129.
# World Perf: Episode 685.000000. Reward 140.000000. action: 0.000000. mean reward 73.059090.
# World Perf: Episode 688.000000. Reward 169.666667. action: 0.000000. mean reward 77.792542.

# %% [markdown]
# ### Checking model representation
# Here we can examine how well the model is able to approximate the true environment after training. The green line indicates the real environment, and the blue indicates model predictions.

# %%
plt.figure(figsize=(8, 12))
for i in range(6):
    plt.subplot(6, 2, 2*i + 1)
    plt.plot(pState[:,i])
    plt.subplot(6,2,2*i+1)
    plt.plot(state_nextsAll[:,i])
plt.tight_layout()
